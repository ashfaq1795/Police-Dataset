# %% [markdown]
# ### Data Analytics Project  :                                                                            Police Dataset
# ###### Students Name: <br> Ashfaq Ahmad (19pwcse1795) <br> Abdul Raheem (19pwcse1789)      <br> <br>    Instructor: Dr. Irfan Abeer

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1. Read dataset

# %%
police_data=pd.read_csv('Police Data.csv')

# %%
police_data
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %% [markdown]
# #### 2. Data cleaning
# As there any missing data?

# %%
police_data.isnull()
# Out:
#        stop_date  stop_time  country_name  driver_gender  driver_age_raw  \
# 0          False      False          True          False           False
# 1          False      False          True          False           False
# 2          False      False          True          False           False
# 3          False      False          True          False           False
# 4          False      False          True          False           False
# ...          ...        ...           ...            ...             ...
# 65530      False      False          True          False           False
# 65531      False      False          True          False           False
# 65532      False      False          True          False           False
# 65533      False      False          True           True            True
# 65534      False      False          True          False           False
#
#        driver_age  driver_race  violation_raw  violation  search_conducted  \
# ...

# %% [markdown]
# Total sum of null values present in each column.

# %%
police_data.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name          65535
# driver_gender          4061
# driver_age_raw         4054
# driver_age             4307
# driver_race            4060
# violation_raw          4060
# violation              4060
# search_conducted          0
# search_type           63056
# stop_outcome           4060
# is_arrested            4060
# stop_duration          4060
# drugs_related_stop        0
# dtype: int64

# %% [markdown]
# As column 3 has equal no of null values as the no of columns so we have to remove it.

# %%
police_data.drop(columns='country_name', inplace=True)
#inplace=ture this argument remove column permenently i,e this column will be missed if we display data again.

# %%
police_data
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %% [markdown]
# #### 3. For speeding, were men or women stopped more often?
# This question is based on filtering and value counting.

# %%
police_data[police_data.violation=='Speeding'].driver_gender.value_counts()
#value_counts is used to see all unique values in a column.
# Out:
# M    25517
# F    11686
# Name: driver_gender, dtype: int64

# %% [markdown]
# From above data, it's cleared that men were more stopped than women for speeding.

# %% [markdown]
# #### 4. Does the gender affect who gets searched during stop?

# %%
police_data.groupby('driver_gender').search_conducted.sum()
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %% [markdown]
# #### 5. What is mean of stop_duration?
# question is related to maping and data type casting

# %%
police_data.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0   1/2/2005      1:55             M          1985.0        20.0       White
# 1  1/18/2005      8:15             M          1965.0        40.0       White
# 2  1/23/2005     23:15             M          1972.0        33.0       White
# 3  2/20/2005     17:15             M          1986.0        19.0       White
# 4  3/14/2005     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted search_type   stop_outcome  \
# 0          Speeding  Speeding             False         NaN       Citation
# 1          Speeding  Speeding             False         NaN       Citation
# 2          Speeding  Speeding             False         NaN       Citation
# 3  Call for Service     Other             False         NaN  Arrest Driver
# 4          Speeding  Speeding             False         NaN       Citation
#
#   is_arrested stop_duration  drugs_related_stop
# ...

# %% [markdown]
# here I have work only with column 'stop_duration' so I am finding its mean while it's in string form.
# So first i will convert it to interger form.

# %%
#first i will check the different values in column.
police_data['stop_duration'].value_counts()
# Out:
# 0-15 Min     47379
# 16-30 Min    11448
# 30+ Min       2647
# 2                1
# Name: stop_duration, dtype: int64

# %% [markdown]
# so I have 4 different values in stop_duration column 3 of them is in string form first i will replace it by integer.

# %%
police_data['stop_duration']=police_data['stop_duration'].map({'0-15 Min':7.5,'16-30 Min':24,'30+ Min':45})
#I replaced given strings by its madian value.

# %%
police_data
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0       1/2/2005      1:55             M          1985.0        20.0
# 1      1/18/2005      8:15             M          1965.0        40.0
# 2      1/23/2005     23:15             M          1972.0        33.0
# 3      2/20/2005     17:15             M          1986.0        19.0
# 4      3/14/2005     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 65530  12/6/2012     17:54             F          1987.0        25.0
# 65531  12/6/2012     22:22             M          1954.0        58.0
# 65532  12/6/2012     23:20             M          1985.0        27.0
# 65533  12/7/2012      0:23           NaN             NaN         NaN
# 65534  12/7/2012      0:30             F          1985.0        27.0
#
#       driver_race                   violation_raw  violation  \
# 0           White                        Speeding   Speeding
# ...

# %%
# Now we have to find mean
police_data['stop_duration'].mean()
# Out:
# 12.187420698181345

# %% [markdown]
# The mean of stop duration for driver either male or female is 12.188

# %% [markdown]
# #### 6. Compare age distribution for each violation.
# this question is related to grouping and then describing.

# %%
police_data.groupby('violation').driver_age.describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
# violation
# Equipment             6507.0  31.682957  11.380671  16.0  23.0  28.0  39.0
# Moving violation     11876.0  36.736443  13.258350  15.0  25.0  35.0  47.0
# Other                 3477.0  40.362381  12.754423  16.0  30.0  41.0  50.0
# Registration/plates   2240.0  32.656696  11.150780  16.0  24.0  30.0  40.0
# Seat belt                3.0  30.333333  10.214369  23.0  24.5  26.0  34.0
# Speeding             37120.0  33.262581  12.615781  15.0  23.0  30.0  42.0
#
#                       max
# violation
# Equipment            81.0
# Moving violation     86.0
# Other                86.0
# Registration/plates  74.0
# Seat belt            42.0
# Speeding             88.0

# %% [markdown]
# The maximum age for drivers they had stopped under Equipment violation is 81.0, minimum age is 16.0, mean is 31.68, std=11.38 , 25% people were 23 year old, 50% were 28 years old, 75% were 39 years old.
#
# Same data for other violations.

# %% [markdown]
# #### Bar chart for male and female drivers violated Traffic rules and regulation.

# %%
male_female=police_data['driver_gender'].value_counts()

# %%
male_female
# Out:
# M    45164
# F    16310
# Name: driver_gender, dtype: int64

# %%
driver_gender=['Male','Female']
data=[45164,16310]
fig, ax=plt.subplots()
bar_width=0.15
bar_M=[0]
bar_F=[1]
plt.bar(bar_M,data[0],color='b',width=bar_width,label='Male')
plt.bar(bar_F,data[1],color='g',width=bar_width,label='Fenale')
plt.xticks([0,1],driver_gender)
plt.xlabel('Driver gender')
plt.ylabel('Megnitude')
plt.title('Male vs Female violation')
plt.legend()

# %% [markdown]
# From the above chart it's cleared that the drives who have violated traffic rules are mostly male.

# %% [markdown]
# ###### Graph for no of drivers (male and female separatly) vs violation

# %%
x=police_data.groupby('violation').driver_gender.value_counts()

# %%
x
# Out:
# violation            driver_gender
# Equipment            M                 5120
#                      F                 1396
# Moving violation     M                 9784
#                      F                 2142
# Other                M                 3129
#                      F                  454
# Registration/plates  M                 1611
#                      F                  632
# Seat belt            M                    3
# Speeding             M                25517
#                      F                11686
# Name: driver_gender, dtype: int64

# %%
violation = ['Equipment', 'Moving violation', 'Other', 'Registration/plates', 'Seat belt', 'Speeding']
driver_gender_M = [5120, 9784, 3129, 1611, 3, 25517]
driver_gender_F = [1396, 2142, 454, 632, 0, 11686]

a = range(len(violation))
fig,ax = plt.subplots(figsize=(12,8))
bar_width = 0.25
opacity = 0.8

bar1 = ax.bar(a, driver_gender_M, bar_width, alpha=opacity, color='b', label='M')   #bar1
bar2 = ax.bar([i + bar_width for i in a], driver_gender_F, bar_width, alpha=opacity, color='r', label='F')  #bar2

ax.set_xlabel('Violation')
ax.set_ylabel('Number of Offenses')
ax.set_title('Violations by Driver Gender')
ax.set_xticks([i + bar_width / 2 for i in a], violation)
ax.legend()
fig.tight_layout()  #This line adjusts the layout of the chart so that all elements are properly spaced and aligned

# %% [markdown]
# From this graph it's cleared that in each violation the male gender has greater average than female.

# %%
y=x.groupby(level=0).sum()   #level=0 represent previous attribute (violation) i,e it will groub by violation.
y
# Out:
# violation
# Equipment               6516
# Moving violation       11926
# Other                   3583
# Registration/plates     2243
# Seat belt                  3
# Speeding               37203
# Name: driver_gender, dtype: int64

# %% [markdown]
# #### Graph for Driver counts (both male and female) vs violation type

# %%
plt.figure(figsize=(12,9))
plt.plot(y,marker='*')
plt.xlabel('types of violation')
plt.ylabel('No of driver')
plt.title('Driver counts vs violation type')
# Out:
# Text(0.5, 1.0, 'Driver counts vs violation type')

# %% [markdown]
# From the above graph it's cleared that maximum violation is "speeding violation" and minimum violation is "seat belt violation".
